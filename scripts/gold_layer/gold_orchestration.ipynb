# %%
NoteBooks = [
    '/Workspace/lakehouse/gold_layer/gold_dim_customers',
    '/Workspace/lakehouse/gold_layer/gold_dim_products',
    '/Workspace/lakehouse/gold_layer/gold_dim_stream',
    '/Workspace/lakehouse/gold_layer/gold_dim_tickets',
    '/Workspace/lakehouse/gold_layer/gold_fact_orders'

    

    ]

# %%
successed_notebook = []
failed_notebook = []

for nb in NoteBooks:

    try :
        result = dbutils.notebook.run(nb, timeout_seconds=0)
        successed_notebook.append(nb)
        print(f'{len(successed_notebook)} is successed')
    except:
        failed_notebook.append(nb)    
        print(f'{len(failed_notebook)} is failed')
