# %%
NoteBooks = [
    '/Workspace/lakehouse/silver_layer/silver_customers',
    '/Workspace/lakehouse/silver_layer/silver_orders',
    '/Workspace/lakehouse/silver_layer/silver_products',
    '/Workspace/lakehouse/silver_layer/silver_stream',
    '/Workspace/lakehouse/silver_layer/silver_tickets'
]

# %%
success_list = []
failed_list = []

for nb in NoteBooks:


    try :
        results = dbutils.notebook.run(nb, timeout_seconds=0)
        success_list.append(nb)

    except Exception  as e :

        failed_list.append(nb)
        raise   



print("Succeeded notebooks:", success_list)
print("Failed notebooks:", failed_list)
# Out:
# Succeeded notebooks: ['/Workspace/lakehouse/silver_layer/silver_customers', '/Workspace/lakehouse/silver_layer/silver_orders', '/Workspace/lakehouse/silver_layer/silver_products', '/Workspace/lakehouse/silver_layer/silver_stream', '/Workspace/lakehouse/silver_layer/silver_tickets']
# Failed notebooks: []
